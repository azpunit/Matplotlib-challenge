# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "/Users/azpunit/Desktop/matplotlib-challenge/data/Mouse_metadata.csv"
study_results_path = "/Users/azpunit/Desktop/matplotlib-challenge/data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_study_df = pd.merge(mouse_metadata, study_results, how='outer', on='Mouse ID')

# Display the data table for preview
mouse_study_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
number_of_mice = len(mouse_study_df["Mouse ID"].unique())
number_of_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
columns = ["Mouse ID", "Drug Regimen", "Sex", "Age_months", "Weight (g)", "Timepoint", "Tumor Volume (mm3)", "Metastatic Sites"]

mouse_duplicates = mouse_study_df.duplicated(subset=["Mouse ID", "Timepoint"])
duplicated_mouse_study_df = mouse_study_df.loc[mouse_duplicates == True, columns]
duplicated_mouse_study_df[["Mouse ID", "Timepoint"]]
# Out:
#     Mouse ID  Timepoint
# 909     g989          0
# 911     g989          5
# 913     g989         10
# 915     g989         15
# 917     g989         20

# %%
# Optional: Get all the data for the duplicate mouse ID. 
columns = ["Mouse ID", "Drug Regimen", "Sex", "Age_months", "Weight (g)", "Timepoint", "Tumor Volume (mm3)", "Metastatic Sites"]

mouse_duplicates = mouse_study_df.duplicated(subset=["Mouse ID", "Timepoint"])
duplicated_mouse_study_df = mouse_study_df.loc[mouse_duplicates == True, columns]
duplicated_mouse_study_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_study = mouse_study_df.drop_duplicates(subset=["Mouse ID", "Timepoint"])
clean_mouse_study
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
number_of_mice_df = len(clean_mouse_study["Mouse ID"].unique())
number_of_mice_df
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# This method is the most straighforward, creating multiple series and putting them all together at the end.
drug_regimen_clean_mouse_study = clean_mouse_study.groupby("Drug Regimen")
index = clean_mouse_study["Drug Regimen"].unique()
mean = drug_regimen_clean_mouse_study["Tumor Volume (mm3)"].mean()
median = drug_regimen_clean_mouse_study["Tumor Volume (mm3)"].median()
variance = drug_regimen_clean_mouse_study["Tumor Volume (mm3)"].var()
standard_deviation = drug_regimen_clean_mouse_study["Tumor Volume (mm3)"].std()
SEM = drug_regimen_clean_mouse_study["Tumor Volume (mm3)"].sem()

raw_summary_statistics = pd.DataFrame({"Mean": mean,
                                       "Median": median,
                                       "Variance": variance,
                                       "Standard Deviation": standard_deviation,
                                       "Standard Error of the Mean": SEM },
                                       index=index)

summary_statistics = raw_summary_statistics.sort_index()

summary_statistics
# Out:
#                 Mean     Median   Variance  Standard Deviation  \
# Capomulin  40.675741  41.557809  24.947764            4.994774
# Ceftamin   52.591172  51.776157  39.290177            6.268188
# Infubinol  52.884795  51.820584  43.128684            6.567243
# Ketapril   55.235638  53.698743  68.553577            8.279709
# Naftisol   54.331565  52.509285  66.173479            8.134708
# Placebo    54.033581  52.288934  61.168083            7.821003
# Propriva   52.393463  50.909965  43.138803            6.568014
# Ramicane   40.216745  40.673236  23.486704            4.846308
# Stelasyn   54.233149  52.431737  59.450562            7.710419
# Zoniferol  53.236507  51.818479  48.533355            6.966589
#
#            Standard Error of the Mean
# Capomulin                    0.329346
# Ceftamin                     0.469821
# Infubinol                    0.492236
# Ketapril                     0.603860
# Naftisol                     0.596466
# Placebo                      0.581331
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# This method produces everything in a single groupby function
drug_regimen_clean_mouse_study = clean_mouse_study.groupby("Drug Regimen")
mean = drug_regimen_clean_mouse_study["Tumor Volume (mm3)"].mean()
median = drug_regimen_clean_mouse_study["Tumor Volume (mm3)"].median()
variance = drug_regimen_clean_mouse_study["Tumor Volume (mm3)"].var()
standard_deviation = drug_regimen_clean_mouse_study["Tumor Volume (mm3)"].std()
SEM = drug_regimen_clean_mouse_study["Tumor Volume (mm3)"].sem()

summary_statistics = pd.DataFrame({"Mean": mean,
                                   "Median": median,
                                   "Variance": variance,
                                   "Standard Deviation": standard_deviation,
                                   "Standard Error of the Mean": SEM
                                  })

summary_statistics
# Out:
#                    Mean     Median   Variance  Standard Deviation  \
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774
# Ceftamin      52.591172  51.776157  39.290177            6.268188
# Infubinol     52.884795  51.820584  43.128684            6.567243
# Ketapril      55.235638  53.698743  68.553577            8.279709
# Naftisol      54.331565  52.509285  66.173479            8.134708
# Placebo       54.033581  52.288934  61.168083            7.821003
# Propriva      52.393463  50.909965  43.138803            6.568014
# Ramicane      40.216745  40.673236  23.486704            4.846308
# Stelasyn      54.233149  52.431737  59.450562            7.710419
# Zoniferol     53.236507  51.818479  48.533355            6.966589
#
#               Standard Error of the Mean
# Drug Regimen
# Capomulin                       0.329346
# Ceftamin                        0.469821
# Infubinol                       0.492236
# Ketapril                        0.603860
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
clean_mouse_study_df = clean_mouse_study.drop_duplicates(subset="Mouse ID")
clean_mouse_study_treatment = clean_mouse_study_df.groupby("Drug Regimen")

number_of_mice_df = clean_mouse_study_treatment["Mouse ID"].count()
new_mouse_study = number_of_mice_df.reset_index()
new_mouse_study_df = new_mouse_study.groupby("Drug Regimen")

data_plot = number_of_mice_df.plot(kind="bar", figsize=(12,10), color="orange", width=0.5, label="Mice Count Evolution")
data_plot.set_xticklabels(new_mouse_study["Drug Regimen"], rotation="horizontal")

data_plot.set_xlim(-0.5, len(new_mouse_study["Drug Regimen"])-0.5)
data_plot.set_ylim(0, max(number_of_mice_df)+1.3)

data_plot.set_title("Number of Mice per Drug", fontsize=13)
data_plot.set_xlabel("Drugs")
data_plot.set_ylabel("Number of Mice")
data_plot.legend(loc="best")

data_plot.plot();

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
clean_mouse_study_df = clean_mouse_study.drop_duplicates(subset="Mouse ID")
clean_mouse_study_treatment_df = clean_mouse_study_df.groupby("Drug Regimen")

clean_drug_study = clean_mouse_study.sort_values("Drug Regimen")
clean_mouse_study_treatment_2_df = clean_drug_study["Drug Regimen"].unique()
clean_mouse_study_treatment_4_df = clean_mouse_study_treatment_df["Mouse ID"].count()

x_axis = np.arange(len(clean_mouse_study_treatment_2_df))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(12,10))
plt.bar(x_axis, clean_mouse_study_treatment_4_df, align="center", color="orange", width=0.5, label="Mice Count Evolution")
plt.xticks(tick_locations, clean_mouse_study_treatment_2_df, rotation="horizontal")

plt.xlim(-0.5, len(x_axis)-0.5)
plt.ylim(0, max(clean_mouse_study_treatment_4_df)+1.3)

plt.title("Number of Mice per Drug", fontsize=13)
plt.xlabel("Drugs")
plt.ylabel("Number of Mice")
plt.legend(loc="best")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
columns = ["Mouse ID", "Drug Regimen", "Sex", "Age_months", "Weight (g)", "Timepoint", "Tumor Volume (mm3)", "Metastatic Sites"]

clean_mouse_gender_study_df = clean_mouse_study.drop_duplicates(subset=["Mouse ID", "Sex"])
colors = ["green", "red"]
explode = (0.01, 0)
labels = clean_mouse_study["Sex"].unique()
male_mice_group = clean_mouse_gender_study_df.loc[clean_mouse_study["Sex"] == "Male", columns]
male_mice_count = len(male_mice_group)
female_mice_group = clean_mouse_gender_study_df.loc[clean_mouse_study["Sex"] == "Female", columns]
female_mice_count = len(female_mice_group)
final_labels = []
for value in labels:
    intermediary_labels = f"{str(value)}"
    final_labels.append(intermediary_labels)
mice_count = [male_mice_count, female_mice_count]

data_pie = pd.DataFrame({"Label": final_labels,
                         "Sex": mice_count
                        })

data_pie_df = data_pie.set_index("Label")

mice_count_plot = data_pie_df.plot(kind="pie", subplots=True, title="Male Mice vs Female Mice Distribution", 
                                   autopct="%1.1f%%", startangle=110, colors=colors, figsize=(5,5),
                                   explode=explode, legend=True)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
columns = ["Mouse ID", "Drug Regimen", "Sex", "Age_months", "Weight (g)", "Timepoint", "Tumor Volume (mm3)", "Metastatic Sites"]

clean_mouse_gender_study_2_df = clean_mouse_study.drop_duplicates(subset=["Mouse ID", "Sex"])
labels = clean_mouse_study["Sex"].unique()
final_labels_df = []
for value in labels:
    intermediary_labels = f"{str(value)}"
    final_labels_df.append(intermediary_labels)
male_mice_group = clean_mouse_gender_study_2_df.loc[clean_mouse_study["Sex"] == "Male", columns]
male_mice_count = len(male_mice_group)
female_mice_group = clean_mouse_gender_study_2_df.loc[clean_mouse_study["Sex"] == "Female", columns]
female_mice_count = len(female_mice_group)
mice_count_df = [male_mice_count, female_mice_count]
colors = ["green", "red"]
explode = (0.1, 0)

plt.figure(figsize=(5.4,4.8))
plt.pie(mice_count_df, explode=explode, labels=final_labels_df, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=110, radius=5)
plt.title("Male Mice vs Female Mice Distribution", pad=40)
plt.legend(loc="best")
plt.ylabel("Sex", labelpad=1)
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
clean_mouse_study_df = clean_mouse_study.groupby("Mouse ID")
clean_last_timepoint = clean_mouse_study_df[["Timepoint"]].max()

raw_last = pd.merge(clean_last_timepoint, clean_mouse_study, how='left', on=['Mouse ID', 'Timepoint'])

intermediary_last = raw_last.loc[(raw_last["Drug Regimen"] == "Capomulin") | (
                                  raw_last["Drug Regimen"] == "Ceftamin") | (
                                  raw_last["Drug Regimen"] == "Infubinol") | (
                                  raw_last["Drug Regimen"] == "Ramicane"), columns]

final_last = intermediary_last.sort_values("Drug Regimen")

final_last
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 116     l897    Capomulin    Male          17          19         45
# 86      j119    Capomulin  Female           7          23         45
# 88      j246    Capomulin  Female          21          21         35
# 193     u364    Capomulin    Male          18          17         45
# 66      g316    Capomulin  Female          22          22         45
# ..       ...          ...     ...         ...         ...        ...
# 92      j913     Ramicane  Female           4          17         45
# 94      j989     Ramicane    Male           8          19         45
# 97      k403     Ramicane    Male          21          16         45
# 120     m546     Ramicane    Male          18          16         45
# 70      g791     Ramicane    Male          11          16         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 116           38.846876                 1
# 86            38.125164                 1
# ...

# %%
columns = ["Mouse ID", "Drug Regimen", "Sex", "Age_months", "Weight (g)", "Timepoint", "Tumor Volume (mm3)", "Metastatic Sites"]

# Put treatments into a list for for loop (and later for plot labels)
drug_list = ["Capomulin", "Ceftamin", "Infubinol", "Ramicane"]

# Create empty list to fill with tumor vol data (for plotting)
data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
data_df = []
data_df_2 = []

for drug in drug_list:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    drug_regimen = final_last.loc[final_last["Drug Regimen"] == drug, columns]
    drug_regimen_df = drug_regimen["Tumor Volume (mm3)"]
    data.append(drug_regimen_df)

lower_bound_list = []
upper_bound_list = []

for drugs_data in data:      
    
    # add subset 
    all_quartiles = drugs_data.quantile([.25,.5,.75])
    first_quartile = all_quartiles[0.25]
    second_quartile = all_quartiles[0.5]
    third_quartile = all_quartiles[0.75]
    inter_quartile_range = third_quartile - first_quartile
    lower_bound = first_quartile - (1.5*inter_quartile_range)
    upper_bound = third_quartile + (1.5*inter_quartile_range)
    analyzed_data = [first_quartile, second_quartile, third_quartile, inter_quartile_range, lower_bound, upper_bound]
    data_df.append(analyzed_data)   

lower_bound_list = [data_df[0][4], data_df[1][4], data_df[2][4], data_df[3][4]]
upper_bound_list = [data_df[0][5], data_df[1][5], data_df[2][5], data_df[3][5]]

zip_object = zip(drug_list, lower_bound_list, upper_bound_list)
for drug_list_i, lower_bound_list_i, upper_bound_list_i in zip_object:

    # Determine outliers using upper and lower bounds
    final_last_df = final_last.loc[(final_last["Drug Regimen"] == drug_list_i) &
                                  (final_last["Tumor Volume (mm3)"] < lower_bound_list_i) |
                                  (final_last["Drug Regimen"] == drug_list_i) &
                                  (final_last["Tumor Volume (mm3)"] > upper_bound_list_i), columns]
    final_last_df_2 = final_last_df["Tumor Volume (mm3)"]
    data_df_2.append(final_last_df_2)

first_quartile_range_list = [data_df[0][0], data_df[1][0], data_df[2][0], data_df[3][0]]
second_quartile_range_list = [data_df[0][1], data_df[1][1], data_df[2][1], data_df[3][1]]
third_quartile_range_list = [data_df[0][2], data_df[1][2], data_df[2][2], data_df[3][2]]
interquartile_range_list = [data_df[0][3], data_df[1][3], data_df[2][3], data_df[3][3]]
lower_bound_range_list = [data_df[0][4], data_df[1][4], data_df[2][4], data_df[3][4]]
upper_bound_range_list = [data_df[0][5], data_df[1][5], data_df[2][5], data_df[3][5]]
formatted_first_quartile_range_list = ["%.6f" % first_quartile_range for first_quartile_range in first_quartile_range_list]
formatted_second_quartile_range_list = ["%.6f" % second_quartile_range for second_quartile_range in second_quartile_range_list]
formatted_third_quartile_range_list = ["%.6f" % third_quartile_range for third_quartile_range in third_quartile_range_list]
formatted_interquartile_range_list = ["%.6f" % interquartile_ranges for interquartile_ranges in interquartile_range_list]
formatted_lower_bound_range_list = ["%.6f" % lower_quartile_range for lower_quartile_range in lower_bound_range_list]
formatted_upper_bound_range_list = ["%.6f" % upper_quartile_range for upper_quartile_range in upper_bound_range_list]

raw_empty_outlier_series = pd.Series([data_df_2[0], data_df_2[1], data_df_2[3]], dtype='int32')
intermediary_outlier_series = raw_empty_outlier_series.str[0]
outlier_series = intermediary_outlier_series.fillna("any")
only_outlier = float(data_df_2[2])
final_only_outlier = ("{:.6f}").format(only_outlier)

print(f"For the Capomulin drug, there isn't {outlier_series[0]} outlier when it comes to the analysis of its tumor volume data.")
print(f"For the Ceftamin drug, there isn't {outlier_series[1]} outlier when it comes to the analysis of its tumor volume data.")
print(f"For the Infubinol drug, there is only one outlier concerning its tumor volume data analysis, which is of about {final_only_outlier}.")
print(f"For the Ramicane drug, there isn't {outlier_series[1]} outlier when it comes to the analysis of its tumor volume data.")

index = ["First Quartile", "Second Quartile", "Third Quartile", "Interquartile Range", "Lower Bound", "Upper Bound"]
capomulin_drug_list = [formatted_first_quartile_range_list[0], formatted_second_quartile_range_list[0], formatted_third_quartile_range_list[0],                                   formatted_interquartile_range_list[0], formatted_lower_bound_range_list[0], formatted_upper_bound_range_list[0]]
ceftamin_drug_list = [formatted_first_quartile_range_list[1], formatted_second_quartile_range_list[1], formatted_third_quartile_range_list[1],                                 formatted_interquartile_range_list[1], formatted_lower_bound_range_list[1], formatted_upper_bound_range_list[1]]
infubinol_drug_list = [formatted_first_quartile_range_list[2], formatted_second_quartile_range_list[2], formatted_third_quartile_range_list[2],                                 formatted_interquartile_range_list[2], formatted_lower_bound_range_list[2], formatted_upper_bound_range_list[2]]
ramicane_drug_list = [formatted_first_quartile_range_list[3], formatted_second_quartile_range_list[3], formatted_third_quartile_range_list[3],                                 formatted_interquartile_range_list[3], formatted_lower_bound_range_list[3], formatted_upper_bound_range_list[3]]

summary_quartiles_and_outliers = pd.DataFrame({"Capomulin Drug": capomulin_drug_list,
                                               "Ceftamin Drug": ceftamin_drug_list,
                                               "Infubinol Drug": infubinol_drug_list,
                                               "Ramicane Drug": ramicane_drug_list},
                                               index=index)
summary_quartiles_and_outliers
# Out:
# For the Capomulin drug, there isn't any outlier when it comes to the analysis of its tumor volume data.
# For the Ceftamin drug, there isn't any outlier when it comes to the analysis of its tumor volume data.
# For the Infubinol drug, there is only one outlier concerning its tumor volume data analysis, which is of about 36.321346.
# For the Ramicane drug, there isn't any outlier when it comes to the analysis of its tumor volume data.
#                     Capomulin Drug Ceftamin Drug Infubinol Drug Ramicane Drug
# First Quartile           32.377357     48.722078      54.048608     31.560470
# Second Quartile          38.125164     59.851956      60.165180     36.561652
# Third Quartile           40.159220     64.299830      65.525743     40.659006
# Interquartile Range       7.781863     15.577752      11.477135      9.098537
# Lower Bound              20.704562     25.355450      36.832905     17.912664
# Upper Bound              51.832015     87.666458      82.741446     54.306811

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, boxplots = plt.subplots()
boxplots.set_title("Four Drug Regimen Boxplots", fontsize=13, pad=10)
boxplots.set_ylabel("Tumor Volume (mm3)")
boxplots.set_xlabel("Drugs")
boxplots.set_xticklabels(drug_list, rotation="horizontal")
red_square = dict(markerfacecolor='r', marker='s')
boxplots.boxplot(data, flierprops=red_square)
boxplots.set_ylim(0, 75)
boxplots.set_xlim(0.6, len(drug_list)+0.3)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
columns = ["Mouse ID", "Drug Regimen", "Sex", "Age_months", "Weight (g)", "Timepoint", "Tumor Volume (mm3)", "Metastatic Sites"]
clean_w914_study = clean_mouse_study.loc[clean_mouse_study["Mouse ID"] == "w914", columns]
timepoint_list = clean_w914_study["Timepoint"]
tumor_volume_list = clean_w914_study["Tumor Volume (mm3)"]

plt.figure(figsize=(10,5))
plt.plot(timepoint_list, tumor_volume_list, marker="s", color="red", label="Tumor Volume Evolution", linewidth=3)

plt.legend(loc="best")
plt.xticks(timepoint_list, rotation="horizontal")

plt.ylim(0, max(tumor_volume_list)+1.5)
plt.xlim(-4.3, max(timepoint_list)+1)

plt.title("Timepoint vs Tumor Volume", fontsize=13)
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")

plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
columns = ["Mouse ID", "Drug Regimen", "Sex", "Age_months", "Weight (g)", "Timepoint", "Tumor Volume (mm3)", "Metastatic Sites"]
clean_capomulin_study = clean_mouse_study.loc[clean_mouse_study["Drug Regimen"] == "Capomulin", columns]
mice_weight_group = clean_capomulin_study.groupby("Weight (g)")
tumor_volume_per_weight = mice_weight_group[["Tumor Volume (mm3)"]].mean()
tumor_volume_per_weight_df = tumor_volume_per_weight.reset_index()
weight_values = tumor_volume_per_weight_df["Weight (g)"]
average_tumor_volume_per_weight = tumor_volume_per_weight_df["Tumor Volume (mm3)"]

plt.figure(figsize=(10,5))
plt.scatter(weight_values, average_tumor_volume_per_weight, marker="o", facecolors="red", edgecolors="black", label="Average Tumor Evolution")

plt.legend(loc="best")
plt.ylim(6, max(average_tumor_volume_per_weight)+2)
plt.xlim(14.6, max(weight_values)+1)

plt.title("Mouse Weight vs Average Tumor Volume", fontsize=13)
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
columns = ["Mouse ID", "Drug Regimen", "Sex", "Age_months", "Weight (g)", "Timepoint", "Tumor Volume (mm3)", "Metastatic Sites"]
clean_capomulin_study = clean_mouse_study.loc[clean_mouse_study["Drug Regimen"] == "Capomulin", columns]
mice_weight_group = clean_capomulin_study.groupby("Weight (g)")
tumor_volume_per_weight = mice_weight_group[["Tumor Volume (mm3)"]].mean()
tumor_volume_per_weight_df = tumor_volume_per_weight.reset_index()
weight_values = tumor_volume_per_weight_df["Weight (g)"]
average_tumor_volume_per_weight = tumor_volume_per_weight_df["Tumor Volume (mm3)"]

avg_slope, avg_int, avg_r, avg_p, avg_stderr = st.linregress(weight_values, average_tumor_volume_per_weight)
regress_values = avg_slope * weight_values + avg_int
average_tumor_volume_per_weight_equation = "y = " + str(round(avg_slope,2)) + "x + " + str(round(avg_int,2))
plt.figure(figsize=(10,5))
plt.scatter(weight_values, average_tumor_volume_per_weight, label="Average Tumor Evolution")
plt.plot(weight_values,regress_values,"r-", linewidth=1.8)
plt.annotate(average_tumor_volume_per_weight_equation, (21,38), fontsize=13, color="red")
plt.legend(loc="best")
plt.ylim(6, max(average_tumor_volume_per_weight)+2)
plt.xlim(14.6, max(weight_values)+1)
plt.title("Mouse Weight vs Average Tumor Volume", fontsize=13)
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")

print(f"The correlation coefficient between the mouse weight and the average tumor volume is of {round(st.pearsonr(weight_values, average_tumor_volume_per_weight)[0],2)}.")
print(f"The equation of the linear regression mode for the 'Mouse Weight vs Average Tumor Volume' scatter plot is of: {average_tumor_volume_per_weight_equation}.")
plt.show()
# Out:
# The correlation coefficient between the mouse weight and the average tumor volume is of 0.95.
# The equation of the linear regression mode for the 'Mouse Weight vs Average Tumor Volume' scatter plot is of: y = 0.89x + 22.76.
